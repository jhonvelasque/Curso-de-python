# %%
import pandas  as pd

# %%
ruta_excel=r'D:\Users\jvelasqu\Desktop\PROYECTOS\curso de python\Parte 7\data\Compras_desde_ads.xlsx'
ruta_xml=r'D:\Users\jvelasqu\Desktop\PROYECTOS\curso de python\Parte 7\data\Valores+de+acciones.xml'

# %%
df1=pd.read_excel(ruta_excel)
df1.head()
# Out:
#    Id_usuario     Genero  Edad  Salario_estimado  Comprado
# 0    15624510  Masculino    19             19000         0
# 1    15810944  Masculino    35             20000         0
# 2    15668575   Femenino    26             43000         0
# 3    15603246   Femenino    27             57000         0
# 4    15804002  Masculino    19             76000         0

# %%
df2=pd.read_xml(ruta_xml)
df2.head()
# Out:
#          date closingValue
# 0  01-05-2023        25,05
# 1  02-05-2023        24,45
# 2  03-05-2023        24,45
# 3  04-05-2023        23,98
# 4  05-05-2023        24,56

# %%
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[23], line 3
#       1 import psycopg2
# ----> 3 conn = psycopg2.connect(
#       4     host="mgq.vps.webdock.cloud",
#       5     port=5432,
#       6     database="dmc",
#       7     user="usr_ro_dmc_rrhh_estudiantes",
#       8     password="12345678",
#       9     sslmode="prefer"
#      10 )
#      12 print("✅ Conexión exitosa")
#      14 # Ejemplo de consulta
#
# File ~\AppData\Roaming\Python\Python313\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# ...
