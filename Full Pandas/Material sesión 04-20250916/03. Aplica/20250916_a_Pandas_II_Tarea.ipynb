# %% [markdown]
# # Ejercicios

# %% [markdown]
# Ej 1. Realizar el equivalente en Python del siguiente query:
# ===
# ```sql
# select
# FUENTE,
# min(CODIGO) as MIN_CODIGO,
# max(CODIGO) as MAX_CODIGO,
# count(DPTO) as COUNT_DPTO
# from df_base
# group by
# FUENTE
# order by
# MIN_CODIGO ASC,
# MAX_CODIGO ASC,
# COUNT_DPTO DESC
#
# ```

# %%
import pandas as pd

df_base = pd.read_csv('https://raw.githubusercontent.com/AngelTintaya/datasets/main/coordenadas.tsv', sep='\t')
df_base.info()  #
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14917 entries, 0 to 14916
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CODIGO  14917 non-null  int64
#  1   FUENTE  14917 non-null  object
#  2   PROV    13438 non-null  object
#  3   DPTO    13438 non-null  object
#  4   DIST    13438 non-null  object
#  5   X       14171 non-null  float64
#  6   Y       14171 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 815.9+ KB

# %% [markdown]
# (ADICIONAL)
# Ej 2. Realizar el equivalente en Python del siguiente query:
# ===
# ```sql
# select
# FUENTE,
# DPTO,
# min(CODIGO) as MIN_CODIGO,
# max(CODIGO) as MAX_CODIGO,
# count(DPTO) as COUNT_DPTO
# from df_base
# group by
# FUENTE,
# DPTO,
# having count(DPTO) > 1
# order by
# FUENTE ASC,
# COUNT_DPTO DESC,
# MIN_CODIGO ASC,
# MAX_CODIGO ASC
#
# ```

# %%
df_base.head(1)
# Out:
#     CODIGO FUENTE      PROV      DPTO   DIST        X       Y
# 0  9700083    API  AREQUIPA  AREQUIPA  VITOR -71.9389 -16.466
